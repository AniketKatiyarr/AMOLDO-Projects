# %%
import pandas as pd

# %%
df = pd.read_csv('nov 22 order report.txt',delimiter='\t')
df
# Out:
#           amazon-order-id  merchant-order-id              purchase-date  \
# 0     171-6005925-3985939                NaN  2022-11-30T18:26:01+00:00
# 1     171-7182847-0535536                NaN  2022-11-30T18:13:23+00:00
# 2     403-9318321-4890715                NaN  2022-11-30T18:13:23+00:00
# 3     407-9161317-2100322                NaN  2022-11-30T18:01:58+00:00
# 4     406-5606526-6944359                NaN  2022-11-30T17:37:12+00:00
# ...                   ...                ...                        ...
# 3137  402-3941926-9443515                NaN  2022-11-01T00:37:57+00:00
# 3138  405-3847728-0857134                NaN  2022-10-31T23:58:39+00:00
# 3139  407-0214942-4324363                NaN  2022-10-31T21:46:53+00:00
# 3140  408-4263119-0113104                NaN  2022-10-31T20:22:50+00:00
# 3141  402-9757103-2507558                NaN  2022-10-31T19:14:14+00:00
#
#               last-updated-date                  order-status  \
# ...

# %%
df.to_excel('November data.xlsx',index=False)
